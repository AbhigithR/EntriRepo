# %% [markdown]
# ## Analysis of Employees in ABC Company

# %% [markdown]
# ##### This analysis aims to explore and analyse a dataset containing information about employees at ABC Company.
#
#
#
#
#
# ######

# %% [markdown]
# ######  Name - Containing the names of the employees . Team - Divided into 30 different teams, representing the team affiliation of each employee
# ###### Number - Representing the count of employees in the company. Position - Divided into five categories (PG, SG, SF, PF, C), indicating the position of each employee.
# ###### Age -  Reflecting the age of the employees. Height - Indicating the height of the employees. Weight - Representing the weight of the employees.
# ###### College - Indicating the colleges of the employees.
# ###### Salary - Representing the salary of the employees

# %% [markdown]
# ## Import modules

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib.ticker import FuncFormatter

# %% [markdown]
# ## Read Data set

# %%
df = pd.read_csv("C:\\Users\\HP\\Downloads\\myexcel - myexcel.csv (1).csv")
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25   168.0     180
# 1    Jae Crowder  Boston Celtics      99       SF   25   155.0     235
# 2   John Holland  Boston Celtics      30       SG   27   166.0     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22   155.0     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29   172.0     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University   947276.0
# 3      Georgia State  1148640.0
# 4           Un Known  5000000.0

# %%
df.tail()
# Out:
#              Name       Team  Number Position  Age  Height  Weight   College  \
# 453  Shelvin Mack  Utah Jazz       8       PG   26   154.0     203    Butler
# 454     Raul Neto  Utah Jazz      25       PG   24   167.0     179  Un Known
# 455  Tibor Pleiss  Utah Jazz      21        C   26   167.0     256  Un Known
# 456   Jeff Withey  Utah Jazz      24        C   26   165.0     231    Kansas
# 457      Priyanka  Utah Jazz      34        C   25   170.0     231    Kansas
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457   947276.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
df.describe(include = 'all')
# Out:
#                  Name                  Team      Number Position         Age  \
# count             458                   458  458.000000      458  458.000000
# unique            458                    30         NaN        5         NaN
# top     Avery Bradley  New Orleans Pelicans         NaN       SG         NaN
# freq                1                    19         NaN      102         NaN
# mean              NaN                   NaN   17.713974      NaN   26.934498
# std               NaN                   NaN   15.966837      NaN    4.400128
# min               NaN                   NaN    0.000000      NaN   19.000000
# 25%               NaN                   NaN    5.000000      NaN   24.000000
# 50%               NaN                   NaN   13.000000      NaN   26.000000
# 75%               NaN                   NaN   25.000000      NaN   30.000000
# max               NaN                   NaN   99.000000      NaN   40.000000
#
# ...

# %%
# To find the null values
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
# to find total null values
df.isnull().sum().sum()
# Out:
# 95

# %%
# to find the duplicated values
df.duplicated().sum()
# Out:
# 0

# %%
# to view column names 
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %% [markdown]
# ## Cleaning the data

# %% [markdown]
# ##### Fill the missing null collages with 'unknown'

# %%
df['College'].fillna(value='Un Known',inplace = True)
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4           Un Known  5000000.0

# %%
 # The Null Values In Collage is Replaced With Un Known
df['College'].isnull().sum()
# Out:
# 0

# %%
# checking the null values in column Salary
df['Salary'].isnull().sum()
# Out:
# 11

# %% [markdown]
# #### Employees with null salary

# %%
df[df['Salary'].isnull()]
# Out:
#                Name                    Team  Number Position  Age  Height  \
# 2      John Holland          Boston Celtics      30       SG   27  06-May
# 46      Elton Brand      Philadelphia 76ers      42       PF   37  06-Sep
# 171   Dahntay Jones     Cleveland Cavaliers      30       SG   35  06-Jun
# 264   Jordan Farmar       Memphis Grizzlies       4       PG   29  06-Feb
# 269    Ray McCallum       Memphis Grizzlies       5       PG   24  06-Mar
# 270  Xavier Munford       Memphis Grizzlies      14       PG   24  06-Mar
# 273  Alex Stepheson       Memphis Grizzlies      35       PF   28  06-Oct
# 350   Briante Weber              Miami Heat      12       PG   23  06-Feb
# 353   Dorell Wright              Miami Heat      11       SF   30  06-Sep
# 397    Axel Toupane          Denver Nuggets       6       SG   23  06-Jul
# 409      Greg Smith  Minnesota Timberwolves       4       PF   25  06-Oct
#
#      Weight                College  Salary
# ...

# %% [markdown]
# ##### The employees with the missing salary is from the positions SG, PF, PG, SF

# %% [markdown]
# #### Most frequently used salary figure of Position SG

# %%
sg_mode =df[df['Position']=='SG']['Salary'].mode().iloc[0] # This is Most Frequently Used
sg_mode
# Out:
# 947276.0

# %%
df[df['Position']=='SG']['Salary'].value_counts()
# Out:
# Salary
# 947276.0      11
# 525093.0       5
# 845059.0       3
# 1015421.0      3
# 16407500.0     2
#               ..
# 14700000.0     1
# 1733040.0      1
# 1449000.0      1
# 15756438.0     1
# 1348440.0      1
# Name: count, Length: 77, dtype: int64

# %% [markdown]
# #### fill the null salary of SG position with the mode

# %%
df.loc[(df['Position'] == 'SG') & (df['Salary'].isnull()), 'Salary'] = sg_mode
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# #### Most frequently used salary figure of the position PG

# %%
pg_mode =df[df['Position']=='PG']['Salary'].mode().iloc[0] 
pg_mode
# Out:
# 947276.0

# %%
df[df['Position']=='PG']['Salary'].value_counts()
# Out:
# Salary
# 947276.0      4
# 845059.0      3
# 13500000.0    2
# 525093.0      2
# 2170465.0     2
#              ..
# 2399040.0     1
# 1824360.0     1
# 6600000.0     1
# 4290000.0     1
# 900000.0      1
# Name: count, Length: 76, dtype: int64

# %% [markdown]
# #### fill the null salary of PG position with the mode

# %%
df.loc[(df['Position'] == 'PG') & (df['Salary'].isnull()), 'Salary'] = pg_mode
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University   947276.0
# 3      Georgia State  1148640.0
# 4           Un Known  5000000.0

# %% [markdown]
# #### Most frequently used salary figure of the position PF

# %%
df[df['Position']=='PF']['Salary'].value_counts()
# Out:
# Salary
# 947276.0     6
# 845059.0     6
# 525093.0     4
# 5000000.0    3
# 8500000.0    3
#             ..
# 4050000.0    1
# 2357760.0    1
# 2943221.0    1
# 5152440.0    1
# 2239800.0    1
# Name: count, Length: 73, dtype: int64

# %%
pf_mode =df[df['Position']=='PF']['Salary'].mode().iloc[0]
pf_mode
# Out:
# 845059.0

# %% [markdown]
# #### fill the null salary of PF position with the mode

# %%
df.loc[(df['Position'] == 'PF') & (df['Salary'].isnull()), 'Salary'] = pf_mode
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# #### Most frequently used salary figure of the position SF

# %%
sf_mode =df[df['Position']=='SF']['Salary'].mode().iloc[0]
sf_mode
# Out:
# 845059.0

# %%
df[df['Position']=='SF']['Salary'].value_counts()
# Out:
# Salary
# 845059.0      5
# 947276.0      4
# 1100602.0     3
# 981348.0      2
# 3382023.0     1
#              ..
# 600000.0      1
# 2841960.0     1
# 17120106.0    1
# 1358880.0     1
# 2050000.0     1
# Name: count, Length: 74, dtype: int64

# %% [markdown]
# #### fill the null salary of SF position with the mode

# %%
df.loc[(df['Position'] == 'SF') & (df['Salary'].isnull()), 'Salary'] = sf_mode
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University   947276.0
# 3      Georgia State  1148640.0
# 4           Un Known  5000000.0

# %% [markdown]
# #### The salary amount that occurs most frequently

# %%
df['Salary'].value_counts()
# Out:
# Salary
# 947276.0      39
# 845059.0      22
# 525093.0      13
# 981348.0       6
# 16407500.0     5
#               ..
# 2100000.0      1
# 1252440.0      1
# 2891760.0      1
# 3272091.0      1
# 900000.0       1
# Name: count, Length: 309, dtype: int64

# %% [markdown]
# ##### Most of the employees at ABC Company are receiving a salary of 947,276.0, followed by those receiving 845,059.0.
# ##### Additionally, there are also unique salary amounts distributed to only one employee, such as 900,000.0, etc.

# %% [markdown]
# ## Arrange the 'height' column with random numbers ranging from 150 to 180.

# %%
df['Height'] = np.random.uniform(150, 180, size = len(df))
df.head()
# Out:
#             Name            Team  Number Position  Age      Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  167.163087     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  154.698842     235
# 2   John Holland  Boston Celtics      30       SG   27  165.203917     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  154.880005     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  171.330096     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University   947276.0
# 3      Georgia State  1148640.0
# 4           Un Known  5000000.0

# %%
df['Height'] = df['Height'].apply(np.ceil)
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25   168.0     180
# 1    Jae Crowder  Boston Celtics      99       SF   25   155.0     235
# 2   John Holland  Boston Celtics      30       SG   27   166.0     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22   155.0     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29   172.0     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University   947276.0
# 3      Georgia State  1148640.0
# 4           Un Known  5000000.0

# %% [markdown]
# ## Number of employees in the Company

# %%
df['Name'].value_counts().sum()
# Out:
# 458

# %% [markdown]
# ## Number of Teams

# %%
df['Team'].nunique()
# Out:
# 30

# %% [markdown]
# ## Name Of The Teams

# %%
df['Team'].unique()
# Out:
# array(['Boston Celtics', 'Brooklyn Nets', 'New York Knicks',
#        'Philadelphia 76ers', 'Toronto Raptors', 'Golden State Warriors',
#        'Los Angeles Clippers', 'Los Angeles Lakers', 'Phoenix Suns',
#        'Sacramento Kings', 'Chicago Bulls', 'Cleveland Cavaliers',
#        'Detroit Pistons', 'Indiana Pacers', 'Milwaukee Bucks',
#        'Dallas Mavericks', 'Houston Rockets', 'Memphis Grizzlies',
#        'New Orleans Pelicans', 'San Antonio Spurs', 'Atlanta Hawks',
#        'Charlotte Hornets', 'Miami Heat', 'Orlando Magic',
#        'Washington Wizards', 'Denver Nuggets', 'Minnesota Timberwolves',
#        'Oklahoma City Thunder', 'Portland Trail Blazers', 'Utah Jazz'],
#       dtype=object)

# %% [markdown]
# ## Number Of Positions

# %%
df['Position'].nunique()
# Out:
# 5

# %% [markdown]
# # Name Of Positions

# %%
df['Position'].unique()
# Out:
# array(['PG', 'SF', 'SG', 'PF', 'C'], dtype=object)

# %% [markdown]
# ## Team with the highest number of employees

# %%
df['Team'].value_counts().idxmax()
# Out:
# 'New Orleans Pelicans'

# %% [markdown]
# ## Team with the lowest number of employees

# %%
df['Team'].value_counts().idxmin()
# Out:
# 'Orlando Magic'

# %% [markdown]
# ## Position with the highest number of employees

# %%
df['Position'].value_counts().idxmax()
# Out:
# 'SG'

# %% [markdown]
# ## Position with the lowest number of employees

# %%
df['Position'].value_counts().idxmin()
# Out:
# 'C'

# %% [markdown]
# ##  Oldest employees

# %%
df[df['Age'] == df['Age'].max()]
# Out:
#               Name                    Team  Number Position  Age  Height  \
# 298     Tim Duncan       San Antonio Spurs      21        C   40   155.0
# 304   Andre Miller       San Antonio Spurs      24       PG   40   175.0
# 400  Kevin Garnett  Minnesota Timberwolves      21       PF   40   171.0
#
#      Weight      College     Salary
# 298     250  Wake Forest  5250000.0
# 304     200         Utah   250750.0
# 400     240     Un Known  8500000.0

# %% [markdown]
# ##### Tim Duncan, Andre Miller, and Kevin Garnett are the oldest employees in the company. Tim Duncan belongs to the San Antonio Spurs team with a
# ##### position of 'C,' Andre Miller belongs to the San Antonio Spurs team with a position of 'PG,' and Kevin Garnett belongs to the Minnesota
# ##### Timberwolves team with a position of 'PF.

# %% [markdown]
# ## Youngest employees

# %%
df[df['Age']== df['Age'].min()]
# Out:
#               Name             Team  Number Position  Age  Height  Weight  \
# 122   Devin Booker     Phoenix Suns       1       SG   19   151.0     206
# 226  Rashad Vaughn  Milwaukee Bucks      20       SG   19   153.0     202
#
#       College     Salary
# 122  Kentucky  2127840.0
# 226      UNLV  1733040.0

# %% [markdown]
# ##### Devin Booker and Rashad Vaughn are employees in the company with the minimum age; both of them are 19 years old.
# ##### They both hold the position of 'SG,'
# ##### with Devin Booker belonging to the Phoenix Suns team and Rashad Vaughn to the Milwaukee Bucks team.

# %% [markdown]
# ## Highest Paid employee

# %%
df[df['Salary'] == df['Salary'].max()]
# Out:
#             Name                Team  Number Position  Age  Height  Weight  \
# 109  Kobe Bryant  Los Angeles Lakers      24       SF   37   166.0     212
#
#       College      Salary
# 109  Un Known  25000000.0

# %% [markdown]
# ##### Kobe Bryant, from the  Team Los Angeles Lakers with the position of 'SF'
# ##### is the highest-paid employee in the company.

# %% [markdown]
# ## Lowest paid employee

# %%
df[df['Salary'] == df['Salary'].min()]
# Out:
#                       Name             Team  Number Position  Age  Height  \
# 32  Thanasis Antetokounmpo  New York Knicks      43       SF   23   164.0
#
#     Weight   College   Salary
# 32     205  Un Known  30888.0

# %% [markdown]
# ##### Thanasis Antetokounmpo, from the New York Knicks with the position of 'SF'
# ##### is the lowest-paid employee in the company.
#
# #### Both the highest-paid and the lowest-paid employees hold the position 'SF'.

# %% [markdown]
# ## Highest paid employees in each position

# %%
df.groupby('Position').apply(lambda x: x[x['Salary'] == x['Salary'].max()])
# Out:
#                        Name                  Team  Number Position  Age  \
# Position
# C        251  Dwight Howard       Houston Rockets      12        C   30
# PF       339     Chris Bosh            Miami Heat       1       PF   32
# PG       100     Chris Paul  Los Angeles Clippers       3       PG   31
# SF       109    Kobe Bryant    Los Angeles Lakers      24       SF   37
# SG       349    Dwyane Wade            Miami Heat       3       SG   34
#
#               Height  Weight       College      Salary
# Position
# C        251   171.0     265      Un Known  22359364.0
# PF       339   163.0     235  Georgia Tech  22192730.0
# PG       100   165.0     175   Wake Forest  21468695.0
# SF       109   166.0     212      Un Known  25000000.0
# SG       349   172.0     220     Marquette  20000000.0

# %% [markdown]
# ##### The highest-paid employee among all positions is Kobe Bryant from the Los Angeles Lakers.
#
# ##### The lowest-paid employee in the highest-paid position is Dwyane Wade from the Miami Heat, in the 'SG' position.
#
# ##### The highest salaries by positions PF and SG are held by the employees from the Miami Heat.
#
# ##### All employees receiving the highest salary in every position are in the age range of 30 to 37.

# %% [markdown]
# ## Lowest paid employees in each position

# %%
 df.groupby('Position').apply(lambda x: x[x['Salary'] == x['Salary'].min()])
# Out:
#                                 Name                  Team  Number Position  \
# Position
# C        135           Alan Williams          Phoenix Suns      15        C
# PF       92               Jeff Ayres  Los Angeles Clippers      19       PF
# PG       130            Phil Pressey          Phoenix Suns      25       PG
# SF       32   Thanasis Antetokounmpo       New York Knicks      43       SF
# SG       291         Orlando Johnson  New Orleans Pelicans       0       SG
#
#               Age  Height  Weight           College    Salary
# Position
# C        135   23   151.0     260  UC Santa Barbara   83397.0
# PF       92    29   156.0     250     Arizona State  111444.0
# PG       130   25   162.0     175          Missouri   55722.0
# SF       32    23   164.0     205          Un Known   30888.0
# SG       291   27   172.0     220  UC Santa Barbara   55722.0

# %% [markdown]
# ##### The highest paid employee among the lowest paid is Jeff Ayres from the Los Angeles Clippers, holding the position of PF.
# ##### The lowest paid employee among the lowest paid is Thanasis Antetokounmpo from New York Knicks, holding the position of 'SF'.
# ##### All employees receiving lower pay in all positions are in the age range of 23 to 29.

# %% [markdown]
# ## Highest paid employees in each team

# %%
df.groupby('Team').apply(lambda x: x[x['Salary'] == x['Salary'].max()]).reset_index(drop = True)
# Out:
#                  Name                    Team  Number Position  Age  Height  \
# 0        Paul Millsap           Atlanta Hawks       4       PF   31   178.0
# 1        Amir Johnson          Boston Celtics      90       PF   29   159.0
# 2         Brook Lopez           Brooklyn Nets      11        C   28   164.0
# 3        Al Jefferson       Charlotte Hornets      25        C   31   165.0
# 4        Derrick Rose           Chicago Bulls       1       PG   27   178.0
# 5        LeBron James     Cleveland Cavaliers      23       SF   31   172.0
# 6     Wesley Matthews        Dallas Mavericks      23       SG   29   176.0
# 7    Danilo Gallinari          Denver Nuggets       8       SF   27   172.0
# 8       Tobias Harris         Detroit Pistons      34       SF   23   153.0
# 9       Klay Thompson   Golden State Warriors      11       SG   26   172.0
# 10      Dwight Howard         Houston Rockets      12        C   30   171.0
# ...

# %% [markdown]
# ##### The highest paid employees are mostly from the SF position, with 10 employees, which is the highest.
# ##### The second highest number comes from the C position, with 7 employees.
# ##### The third highest is the PG position, with 6 employees.
# ##### The second-to-last is PF with 5 employees, and the last is SG with 3 employees.
# ##### The highest paid employee among all teams is Kobe Bryant from the Los Angeles Lakers, in the  'SF' position.
# ##### The lowest among all the highest-paid employees is Carl Landry from the Philadelphia 76ers, in the  'PF' position .
# ##### Additionally, the Phoenix Suns have two employees, Eric Bledsoe and Brandon Knight, both with the same highest salary amount, and both in the PG position.

# %% [markdown]
# ## Lowest paid employees in each team

# %%
df.groupby('Team').apply(lambda x: x[x['Salary'] == x['Salary'].min()]).reset_index(drop = True)
# Out:
#                       Name                    Team  Number Position  Age  \
# 0          Lamar Patterson           Atlanta Hawks      13       SG   24
# 1             John Holland          Boston Celtics      30       SG   27
# 2          Sean Kilpatrick           Brooklyn Nets       6       SG   26
# 3          Jorge Gutierrez       Charlotte Hornets      12       PG   27
# 4        Cristiano Felicio           Chicago Bulls       6       PF   23
# 5             Jordan McRae     Cleveland Cavaliers      12       SG   25
# 6              Salah Mejri        Dallas Mavericks      50        C   29
# 7           JaKarr Sampson          Denver Nuggets       9       SG   23
# 8            Lorenzo Brown         Detroit Pistons      17       PG   25
# 9         Anderson Varejao   Golden State Warriors      18       PF   33
# 10        Andrew Goudelock         Houston Rockets       0       PG   27
# 11               Ty Lawson          Indiana Pacers      10       PG   28
# ...

# %% [markdown]
# ##### The PG position has more employees with the lowest salary, with a total of 9.
# ##### The second positions are SG and PF, both with 8 employees each.
# ##### The third is SF, with 5 employees, and the least is C, with only 2 employees.
# ##### The highest-paid employee among the lowest paid is John Holland from the Boston Celtics, in the position of 'SG'.
# ##### The lowest-paid employees among the lowest paid are Thanasis Antetokounmpo from the New York Knicks, in the position of SF.
# ##### Additionally, employees T.J. McConnell and Christian Wood from the Philadelphia 76ers share the lowest-paid designation from the team.

# %% [markdown]
# ### Number of Employees in Each Position

# %%
df['Position'].value_counts()
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %% [markdown]
# ### Percentage of employees in each position

# %%
position_counts = df['Position'].value_counts()

# Plot a pie chart
plt.figure(figsize=(6, 6))
position_counts.plot.pie(autopct='%1.1f%%', startangle=90)
plt.title('PERCENTAGE OF EMPLOYEES IN EACH POSITION')
plt.ylabel('')
plt.show()

# %% [markdown]
# ##### The position with the highest number of employees is SG, with 102 employees, constituting 22.3% of the total.
# ##### The second most common position is PF, with 100 employees, accounting for 21.8%.
# ##### The third position, PG, has 92 employees, making up 20.1% Following this, SF is the fourth position, with 85 employees, representing 18.6%.
# ##### The last position, C, has 79 employees, comprising 17.2%.

# %% [markdown]
# ## 1. How many are there in each Team and the percentage splitting with respect to the total
# ## employees ?

# %% [markdown]
# ## Number of employees in each team

# %%
df['Team'].value_counts()
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %% [markdown]
# ## Number of employees in each team

# %%
team_counts = df['Team'].value_counts()
plt.figure(figsize=(15,5))
team_counts.plot(kind = 'bar', color= 'skyblue')
plt.title('NUMBER OF EMPLOYEES IN EACH TEAM')
plt.xlabel('TEAM')
plt.ylabel('NUMBER OF EMPLOYEES')
plt.yticks(range(0, max(team_counts) +1, 2))
plt.show()

# %% [markdown]
# ## The Percentage of Employees in each Team

# %%
team_percentages = (df['Team'].value_counts() / len(df)) * 100
plt.figure(figsize=(12, 17))
plt.pie(team_percentages, labels=team_percentages.index, autopct='%1.1f%%', startangle=55)
plt.title('PERCENTAGE OF EMPLOYEES IN EACH TEAM')
plt.show()

# %% [markdown]
# ##### The total number of employees in ABC Company is 458, distributed among 30 teams and 5 positions.
# ##### The team with the highest number of employees is the New Orleans Pelicans, totaling 19 employees, constituting 4.1% of the total workforce.
# ##### The second most populated team is the Memphis Grizzlies, with 18 employees, accounting for 3.9% of the total employees.
# ##### Teams like the Utah Jazz and the New York Knicks have a population of 16 employees each, representing 3.5% each.
# ##### The other 24 teams have 15 employees each, constituting 3.3% of the workforce for each team.
# ##### The teams with the fewest number of employees are the Orlando Magic and the Minnesota Timberwolves, each with a population of 14 members, and
# ##### each team represents 3.1% of the total workforce.rce..

# %% [markdown]
# ## 2. Segregate the employees w.r.t different positions ?

# %% [markdown]
# #### Group the employees in the company based on the positions they have held

# %%
position_groups = df.groupby('Position')
position_dataframes = {}

for position, group_data in position_groups:
    position_dataframes[position] = group_data

sg_group = position_dataframes.get('SG', pd.DataFrame())
pg_group = position_dataframes.get('PG', pd.DataFrame())
pf_group = position_dataframes.get('PF', pd.DataFrame())
c_group = position_dataframes.get('C', pd.DataFrame())
sf_group = position_dataframes.get('SF', pd.DataFrame())

sg_group.reset_index(drop=True, inplace=True)
pg_group.reset_index(drop=True, inplace=True)
pf_group.reset_index(drop=True, inplace=True)
c_group.reset_index(drop=True, inplace=True)
sf_group.reset_index(drop=True, inplace=True)

# %%
sg_group.head()
# Out:
#                Name            Team  Number Position  Age  Height  Weight  \
# 0      John Holland  Boston Celtics      30       SG   27   166.0     205
# 1       R.J. Hunter  Boston Celtics      28       SG   22   155.0     185
# 2       Evan Turner  Boston Celtics      11       SG   27   154.0     220
# 3       James Young  Boston Celtics      13       SG   20   180.0     215
# 4  Bojan Bogdanovic   Brooklyn Nets      44       SG   27   159.0     216
#
#              College     Salary
# 0  Boston University   947276.0
# 1      Georgia State  1148640.0
# 2         Ohio State  3425510.0
# 3           Kentucky  1749840.0
# 4           Un Known  3425510.0

# %%
pg_group.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25   168.0     180
# 1   Terry Rozier  Boston Celtics      12       PG   22   175.0     190
# 2   Marcus Smart  Boston Celtics      36       PG   22   161.0     220
# 3  Isaiah Thomas  Boston Celtics       4       PG   27   174.0     185
# 4   Jarrett Jack   Brooklyn Nets       2       PG   32   159.0     200
#
#           College     Salary
# 0           Texas  7730337.0
# 1      Louisville  1824360.0
# 2  Oklahoma State  3431040.0
# 3      Washington  6912869.0
# 4    Georgia Tech  6300000.0

# %%
pf_group.head()
# Out:
#                Name            Team  Number Position  Age  Height  Weight  \
# 0     Jonas Jerebko  Boston Celtics       8       PF   29   172.0     231
# 1      Amir Johnson  Boston Celtics      90       PF   29   159.0     240
# 2     Jordan Mickey  Boston Celtics      55       PF   21   163.0     235
# 3  Chris McCullough   Brooklyn Nets       1       PF   21   158.0     200
# 4       Willie Reed   Brooklyn Nets      33       PF   26   154.0     220
#
#        College      Salary
# 0     Un Known   5000000.0
# 1     Un Known  12000000.0
# 2          LSU   1170960.0
# 3     Syracuse   1140240.0
# 4  Saint Louis    947276.0

# %%
c_group.head()
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0     Kelly Olynyk  Boston Celtics      41        C   25   163.0     238
# 1  Jared Sullinger  Boston Celtics       7        C   24   177.0     260
# 2     Tyler Zeller  Boston Celtics      44        C   26   176.0     253
# 3      Brook Lopez   Brooklyn Nets      11        C   28   164.0     275
# 4       Henry Sims   Brooklyn Nets      14        C   26   155.0     248
#
#           College      Salary
# 0         Gonzaga   2165160.0
# 1      Ohio State   2569260.0
# 2  North Carolina   2616975.0
# 3        Stanford  19689000.0
# 4      Georgetown    947276.0

# %% [markdown]
# # 3 . From which age group most Of employees belongs To ?

# %% [markdown]
# ## Most frequently occuring age group

# %%
df['Age'].mode()
# Out:
# 0    24
# Name: Age, dtype: int64

# %% [markdown]
# ## Number of employees from different age group

# %%
df['Age'].value_counts()
# Out:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: count, dtype: int64

# %% [markdown]
# ## Age Distribution of Employees

# %%
age_counts = df['Age'].value_counts().sort_index()

plt.hist(df['Age'], bins=len(age_counts), edgecolor='black', alpha=0.7)
plt.title('Age Distribution of Employees')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### The most common age among ABC Company employees is 24, with a frequency of 47.
# ##### The second most common age is 25, with a frequency of 46.
# ##### The majority of employees fall within the age range of 20 to the early 30s.
# ##### Additionally, there is a decline in frequency as age increases after the mid-20s, with a significant drop occurring after the age of 31.
# ##### The age groups with the lowest frequency among employees are 19 and 39, each occurring only twice.

# %% [markdown]
# ## 4. Find Out which  team and position spending in tearms of salary is high ?

# %% [markdown]
# ### Total salary spending by the company

# %%
df['Salary'].sum()
# Out:
# 2170795555.0

# %% [markdown]
# #### Total salary spending For each position

# %%
position_total_salary = df.groupby('Position')['Salary'].sum()

print("Total salary for each position:")
print(position_total_salary)
# Out:
# Total salary for each position:
# Position
# C     466377332.0
# PF    445096027.0
# PG    450638075.0
# SF    408866035.0
# SG    399818086.0
# Name: Salary, dtype: float64

# %% [markdown]
# ## Total Salary by position

# %%
position_total_salary = df.groupby('Position')['Salary'].sum().reset_index()

position_total_salary = position_total_salary.sort_values(by='Salary', ascending=False)
color = 'blue', 'green', 'red', 'orange', 'purple'

plt.figure(figsize=(10, 6))
bars = plt.bar(position_total_salary['Position'], position_total_salary['Salary'], color= color)

plt.xlabel('POSITION')
plt.ylabel('TOTAL SALARY')
plt.title('TOTAL SALARY BY POSITION')
plt.xticks(rotation=360, ha='right')
def format_ticks(value, _):
    return f'{int(value):,}'
plt.gca().yaxis.set_major_formatter(FuncFormatter(format_ticks))

plt.show()

# %% [markdown]
# #### Percentage of salary by each position

# %%
position_total_salary = df.groupby('Position')['Salary'].sum().reset_index()


position_total_salary = position_total_salary.sort_values(by='Salary', ascending=False)

# Pie chart
plt.figure(figsize=(10, 6))
plt.pie(position_total_salary['Salary'], labels=position_total_salary['Position'], autopct='%1.1f%%', colors=['pink', 'orange', 'lightskyblue', 'lightgreen', 'red'])
plt.title('PERCENTAGE OF TOTAL SALARY BY POSITION')
plt.show()

# %% [markdown]
# #####  The position receiving the highest salary is 'C', with a total amount of 466,377,332.0, representing 21.5% of the total salary across all positions in the company.
# ##### Interestingly, 'C' is the least populated position among all positions in the company.
# #####  The second-highest is the position named 'PG', receiving a total amount of 450,638,075.0, which accounts for 20.8% and stands as the second-best among the five positions.
# #####  The third position, both in terms of the percentage of salary and the total amount, is held by the position 'PF', receiving 445,096,027.0, equivalent to 20.5%.
# #####  The second-to-last position in terms of total salary is 'SF', with an amount of 408,866,035.0, representing 18.8%.
# #####  The position with the lowest salary is 'SG', receiving 399,818,086.0 and accounting for 18.4%. Notably, 'SG' has the highest number of
# ##### employees in the company.

# %% [markdown]
# ### Total Salary of Each Team

# %%
position_total_salary = df.groupby('Team')['Salary'].sum().reset_index()
position_total_salary = position_total_salary.sort_values(by='Salary', ascending=False)

print("Total salary for each team (sorted in ascending order):")
print(position_total_salary)
# Out:
# Total salary for each team (sorted in ascending order):
#                       Team       Salary
# 5      Cleveland Cavaliers  107935965.0
# 12    Los Angeles Clippers   94854640.0
# 20   Oklahoma City Thunder   93765298.0
# 9    Golden State Warriors   88868997.0
# 4            Chicago Bulls   86783378.0
# 26       San Antonio Spurs   84442733.0
# 15              Miami Heat   84308008.0
# 18    New Orleans Pelicans   82750774.0
# 14       Memphis Grizzlies   80237767.0
# 3        Charlotte Hornets   78340920.0
# 29      Washington Wizards   76328636.0
# 10         Houston Rockets   75283021.0
# 19         New York Knicks   73303898.0
# 0            Atlanta Hawks   72902950.0
# 13      Los Angeles Lakers   71770431.0
# 25        Sacramento Kings   71683666.0
# 6         Dallas Mavericks   71198732.0
# 27         Toronto Raptors   71117611.0
# 16         Milwaukee Bucks   69603517.0
# 8          Detroit Pistons   67168263.0
# 11          Indiana Pacers   66751826.0
# ...

# %% [markdown]
# ## Total Salary for each team

# %%
team_total_salary = position_total_salary.sort_values(by='Salary', ascending=False)  # Sort the DataFrame by 'Salary' column in descending order

plt.figure(figsize=(12, 6))
bars = plt.bar(team_total_salary['Team'], team_total_salary['Salary'], color='purple')

plt.xlabel('TEAM')
plt.ylabel('TOTAL SALARY')
plt.title('TOTAL SALARY BY TEAM')
plt.xticks(rotation=90, ha='right')

def format_ticks(value, _):
    return f'{int(value):,}'

plt.gca().yaxis.set_major_formatter(FuncFormatter(format_ticks))

plt.show()

# %% [markdown]
# ## Percentage of salary by each team

# %%
team_total_salary = df.groupby('Team')['Salary'].sum().reset_index()

team_total_salary = team_total_salary.sort_values(by='Salary', ascending=False)

plt.figure(figsize=(14, 17))
plt.pie(team_total_salary['Salary'], labels=team_total_salary['Team'], autopct='%1.1f%%', colors=['skyblue', 'orange', 'red', 'green'])
plt.title('PERCENTAGE OF TOTAL SALARY BY TEAM')
plt.show()

# %% [markdown]
# ##### The total salary expenditure for all teams in the company amounts to 2170795555.0
# #####
# ##### Notably, the Cleveland Cavaliers have the highest total salary, amounting to 107,935,965.0, which constitutes 5.0% of the overall total.
# ##### The Los Angeles Clippers follow closely as the second-highest paid team, with a salary package of 94,854,640.00, representing 4.4% of the total salary.
# ##### On the other end, the team with the lowest salary is the Philadelphia 76ers, earning 30,992,894.00, accounting for only 1.4% of the total salary.

# %% [markdown]
# # 5 Find if there is any correlation between age and salary , represent it visually ?

# %% [markdown]
# ## Calculating the correlation between age and salary

# %%
correlation = df['Age'].corr(df['Salary'])

print(f"Correlation between Age and Salary: {correlation}")
# Out:
# Correlation between Age and Salary: 0.20638882130797304

# %% [markdown]
# ## Correlation between Age and Salary

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Age'], df['Salary'], color='green', alpha=0.7)
plt.title('CORRELATION BETWEEN AGE AND SALARY')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.grid(True)

# Add a regression line
sns.regplot(x='Age', y='Salary', data=df, scatter=False, color='blue')

plt.show()

# %% [markdown]
# ##### In ABC Company, the age of employees ranges from a minimum of 19 to a maximum of 40.
# ##### A positive correlation exists between age and salary,  indicating that, on average, as employees' age increases, their salary tends to rise.
# ##### However, it's important to note that we cannot pinpoint a specific rate of increase between age and salary.
# ##### The correlation coefficient between age and salary is 0.20, signifying a weak positive
# ##### correlation, which implies that other factors beyond age play a significant role in determining salary levels.
